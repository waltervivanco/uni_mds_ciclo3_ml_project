# %% [markdown]
# Cargar librerías

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

sns.set(style="whitegrid")

# %% [markdown]
# Cargar el dataset

# %%
import pandas as pd
import re
from pathlib import Path

file_path = Path("TL-20240723-202614 WA1200 #05.csv")

with open(file_path, "r", encoding="utf-8", errors="replace") as f:
    rows = [line.rstrip("\n\r").split(";") for line in f]

# Fila 19 y 20 (1-indexadas) -> indices 18 y 19
vars_row = [str(x).strip() for x in rows[18]]
units_row = [str(x).strip() for x in rows[19]]

n = max(len(vars_row), len(units_row))
vars_row += [""] * (n - len(vars_row))
units_row += [""] * (n - len(units_row))

def fix_text(s):
    s = str(s)
    replacements = {
        "Mi¿½ltiple": "Multiple",
        "Mï¿½ltiple": "Multiple",
        "M�ltiple": "Multiple",
        "Operaci�n": "Operacion",
        "Reconstrucci�n": "Reconstruccion",
        "Presi�n": "Presion",
        "C�rter": "Carter",
        "Barom�trica": "Barometrica",
        "Admisi�n": "Admision",
        "�ndice": "Indice",
        "Bater�": "Bateria",
        "Sincronizaci": "Sincronizacion",
        "�F": "F",
        "Â°F": "F",
    }
    for bad, good in replacements.items():
        s = s.replace(bad, good)
    s = re.sub(r"\s+", " ", s).strip()
    return s

def merge_name_unit(var, unit):
    var = fix_text(var)
    unit = fix_text(unit)

    if unit == "" or unit.lower() == "unidades":
        col = var
    elif var == "":
        col = f"[{unit}]"
    else:
        col = f"{var} [{unit}]"

    # Regla: toda columna de temperatura queda con [F]
    if re.search(r"temperatura", col, flags=re.IGNORECASE):
        if re.search(r"\[[^\]]*\]", col):
            col = re.sub(r"\[[^\]]*\]", "[F]", col)
        else:
            col = f"{col} [F]"

    return col

new_cols = [merge_name_unit(v, u) for v, u in zip(vars_row, units_row)]

# Datos desde fila 21
data_rows = []
for r in rows[20:]:
    r = [str(x).strip() for x in r]
    r = (r + [""] * n)[:n]
    data_rows.append(r)

df = pd.DataFrame(data_rows, columns=new_cols)

# Quitar columnas vacias de forma compatible con pandas antiguo
keep_cols = []
for c in df.columns:
    name_empty = (str(c).strip() == "")
    col_empty = df[c].astype(str).str.strip().eq("").all()
    if not (name_empty and col_empty):
        keep_cols.append(c)
df = df[keep_cols]

# Quitar filas totalmente vacias
df = df[df.astype(str).apply(lambda r: r.str.strip().ne("").any(), axis=1)].reset_index(drop=True)

print("Tamanio:", df.shape)
display(df.head(20))
# Out:
# Tamanio: (1245, 53)
#    Evento   Tiempo Real Tiempo del Motor  \
# 0       1  Sin Preparar     002053:24:49
# 1       2  Sin Preparar     002053:26:31
# 2       3  Sin Preparar     002053:27:35
# 3       4  Sin Preparar     002053:28:47
# 4       5  Sin Preparar     002053:29:55
# 5       6  Sin Preparar     002053:31:06
# 6       7  Sin Preparar     002053:33:03
# 7       8  Sin Preparar     002053:34:43
# 8       9  Sin Preparar     002053:35:10
# 9      10  Sin Preparar     002053:35:51
# 10     11  Sin Preparar     002053:36:32
# 11     12  Sin Preparar     002053:37:18
# 12     13  Sin Preparar     002053:38:56
# 13     14  Sin Preparar     002053:40:57
# 14     15  Sin Preparar     002053:41:43
# 15     16  Sin Preparar     002053:44:46
# 16     17  Sin Preparar     002053:47:57
# 17     18  Sin Preparar     002053:51:43
# 18     19  Sin Preparar     002054:08:31
# 19     20  Sin Preparar     002054:09:17
#
#    Tiempo de Operacion de Reconstruccion del M [HHHHHH:MM]  \
# 0                                          0002053:24
# 1                                          0002053:26
# 2                                          0002053:27
# 3                                          0002053:28
# 4                                          0002053:29
# 5                                          0002053:31
# 6                                          0002053:33
# 7                                          0002053:34
# 8                                          0002053:35
# 9                                          0002053:35
# 10                                         0002053:36
# 11                                         0002053:37
# 12                                         0002053:38
# 13                                         0002053:40
# 14                                         0002053:41
# 15                                         0002053:44
# 16                                         0002053:47
# 17                                         0002053:51
# 18                                         0002054:08
# 19                                         0002054:09
#
#    Velocidad del Motor [rpm]  \
# 0                       1820
# 1                       1829
# 2                       1852
# 3                       1824
# 4                       1819
# 5                       1855
# 6                       1852
# 7                       1660
# 8                       1852
# 9                       1817
# 10                      1772
# 11                      1783
# 12                      1751
# 13                      1768
# 14                      1916
# 15                      1860
# 16                      1859
# 17                      1855
# 18                      1784
# 19                      1856
#
#    Por Ciento de Pedal o Palanca del Acelerador [Percent]  \
# 0                                                  90
# 1                                                 100
# 2                                                 100
# 3                                                 100
# 4                                                 100
# 5                                                 100
# 6                                                 100
# 7                                                 100
# 8                                                 100
# 9                                                 100
# 10                                                100
# 11                                                 97
# 12                                                100
# 13                                                100
# 14                                                100
# 15                                                 92
# 16                                                 89
# 17                                                100
# 18                                                 84
# 19                                                100
#
#    Temperatura del Refrigerante del Motor [F]  \
# 0                                       183.2
# 1                                         185
# 2                                       188.6
# 3                                       190.4
# 4                                         194
# 5                                       195.8
# 6                                       195.8
# 7                                       195.8
# 8                                       195.8
# 9                                       197.6
# 10                                      199.4
# 11                                      201.2
# 12                                      199.4
# 13                                      197.6
# 14                                      201.2
# 15                                        203
# 16                                      201.2
# 17                                      190.4
# 18                                        185
# 19                                      186.8
#
#    Sensor de Presion del Refrigeran [in Hg] Presion de Aceite del Mot [psi]  \
# 0                                        30                            67.9
# 1                                        27                            68.5
# 2                                        27                            69.6
# 3                                        34                            66.7
# 4                                        32                              69
# 5                                        33                            66.7
# 6                                        32                            67.3
# 7                                        33                            62.7
# 8                                        33                            66.1
# 9                                        38                            66.1
# 10                                       33                            62.1
# 11                                       34                            64.4
# 12                                       37                            66.7
# 13                                       34                            63.8
# 14                                       38                            66.1
# 15                                       36                            67.3
# 16                                       29                              65
# 17                                       31                            66.7
# 18                                       36                            70.8
# 19                                       33                            72.5
#
#    Temperatura de Aceite del Motor [F]  ...  \
# 0                                199.4  ...
# 1                                201.8  ...
# 2                                205.4  ...
# 3                                  208  ...
# 4                                210.3  ...
# 5                                212.2  ...
# 6                                211.9  ...
# 7                                214.1  ...
# 8                                214.8  ...
# 9                                214.8  ...
# 10                               217.3  ...
# 11                               219.2  ...
# 12                               217.2  ...
# 13                               217.7  ...
# 14                               219.3  ...
# 15                               220.8  ...
# 16                               215.2  ...
# 17                               209.7  ...
# 18                               194.8  ...
# 19                               199.1  ...
#
#    Sensor 1 de Temperatura del Multiple de Admisi [F]  \
# 0                                                 124
# 1                                                 129
# 2                                                 135
# 3                                                 140
# 4                                                 142
# 5                                                 144
# 6                                                 140
# 7                                                 140
# 8                                                 142
# 9                                                 144
# 10                                                145
# 11                                                149
# 12                                                140
# 13                                                142
# 14                                                145
# 15                                                144
# 16                                                133
# 17                                                127
# 18                                                129
# 19                                                133
#
#    Sensor 2 de Temperatura del Multiple de Admisi [F]  \
# 0                                                 127
# 1                                                 131
# 2                                                 136
# 3                                                 141
# 4                                                 143
# 5                                                 145
# 6                                                 141
# 7                                                 140
# 8                                                 143
# 9                                                 146
# 10                                                147
# 11                                                148
# 12                                                142
# 13                                                143
# 14                                                146
# 15                                                146
# 16                                                137
# 17                                                131
# 18                                                131
# 19                                                133
#
#    Sensor 3 de Temperatura del Multiple de Admisi [F]  \
# 0                                                 125
# 1                                                 129
# 2                                                 134
# 3                                                 139
# 4                                                 141
# 5                                                 143
# 6                                                 139
# 7                                                 139
# 8                                                 142
# 9                                                 144
# 10                                                145
# 11                                                147
# 12                                                140
# 13                                                141
# 14                                                144
# 15                                                144
# 16                                                135
# 17                                                129
# 18                                                130
# 19                                                131
#
#    Sensor 4 de Temperatura del Multiple de Admisi [F]  \
# 0                                                 129
# 1                                                 133
# 2                                                 138
# 3                                                 143
# 4                                                 145
# 5                                                 146
# 6                                                 142
# 7                                                 143
# 8                                                 145
# 9                                                 147
# 10                                                149
# 11                                                150
# 12                                                144
# 13                                                145
# 14                                                148
# 15                                                147
# 16                                                140
# 17                                                132
# 18                                                133
# 19                                                136
#
#    Sensor de Temperatura 1 Delta del Multiple de Admision (Calcul [F]  \
# 0                                                  32
# 1                                                  34
# 2                                                  34
# 3                                                  34
# 4                                                  34
# 5                                                  34
# 6                                                  34
# 7                                                  34
# 8                                                  34
# 9                                                  32
# 10                                                 32
# 11                                                 32
# 12                                                 32
# 13                                                 32
# 14                                                 34
# 15                                                 32
# 16                                                 32
# 17                                                 32
# 18                                                 34
# 19                                                 34
#
#    Sensor de Temperatura 2 Delta del Multiple de Admision (Calcul [F]  \
# 0                                                  33
# 1                                                  33
# 2                                                  33
# 3                                                  33
# 4                                                  33
# 5                                                  33
# 6                                                  33
# 7                                                  32
# 8                                                  33
# 9                                                  33
# 10                                                 33
# 11                                                 32
# 12                                                 32
# 13                                                 33
# 14                                                 33
# 15                                                 32
# 16                                                 31
# 17                                                 33
# 18                                                 33
# 19                                                 32
#
#    Sensor de Temperatura 3 Delta del Multiple de Admision (Calcul [F]  \
# 0                                                  33
# 1                                                  33
# 2                                                  33
# 3                                                  33
# 4                                                  33
# 5                                                  33
# 6                                                  33
# 7                                                  33
# 8                                                  33
# 9                                                  33
# 10                                                 33
# 11                                                 32
# 12                                                 32
# 13                                                 33
# 14                                                 32
# 15                                                 32
# 16                                                 31
# 17                                                 33
# 18                                                 33
# 19                                                 32
#
#    Sensor de Temperatura 4 Delta del Multiple de Admision (Calcul [F]  \
# 0                                                  33
# 1                                                  33
# 2                                                  33
# 3                                                  33
# 4                                                  33
# 5                                                  33
# 6                                                  33
# 7                                                  33
# 8                                                  33
# 9                                                  33
# 10                                                 33
# 11                                                 33
# 12                                                 32
# 13                                                 33
# 14                                                 32
# 15                                                 32
# 16                                                 31
# 17                                                 33
# 18                                                 34
# 19                                                 33
#
#    Carga Neta Porcentual [Percent] Estado del Motor
# 0                               66      Funcionando
# 1                               68      Funcionando
# 2                               63      Funcionando
# 3                               73      Funcionando
# 4                              100      Funcionando
# 5                               61      Funcionando
# 6                               64      Funcionando
# 7                               92      Funcionando
# 8                               61      Funcionando
# 9                               55      Funcionando
# 10                              83      Funcionando
# 11                              96      Funcionando
# 12                              60      Funcionando
# 13                              57      Funcionando
# 14                              93      Funcionando
# 15                              96      Funcionando
# 16                              63      Funcionando
# 17                              96      Funcionando
# 18                              58      Funcionando
# 19                              82      Funcionando
#
# [20 rows x 53 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1245 entries, 0 to 1244
# Data columns (total 53 columns):
#  #   Column                                                                Non-Null Count  Dtype
# ---  ------                                                                --------------  -----
#  0   Evento                                                                1245 non-null   object
#  1   Tiempo Real                                                           1245 non-null   object
#  2   Tiempo del Motor                                                      1245 non-null   object
#  3   Tiempo de Operacion de Reconstruccion del M [HHHHHH:MM]               1245 non-null   object
#  4   Velocidad del Motor [rpm]                                             1245 non-null   object
#  5   Por Ciento de Pedal o Palanca del Acelerador [Percent]                1245 non-null   object
#  6   Temperatura del Refrigerante del Motor [F]                            1245 non-null   object
#  7   Sensor de Presion del Refrigeran [in Hg]                              1245 non-null   object
#  8   Presion de Aceite del Mot [psi]                                       1245 non-null   object
#  9   Temperatura de Aceite del Motor [F]                                   1245 non-null   object
#  10  Presion del Carter del M [pulg. H2O]                                  1245 non-null   object
#  11  Presion Pre Filtro de Acei [psi]                                      1245 non-null   object
#  12  Presion Post Filtro de Acei [psi]                                     1245 non-null   object
#  13  Sensor de Presion Diferencial del Filtro de Aceite (Calculad [in Hg]  1245 non-null   object
#  14  Presion Barometrica del [in Hg]                                       1245 non-null   object
#  15  Temperatura del Aire de Admision del Compresor del Turbocargad [F]    1245 non-null   object
#  16  Sensor de Temperatura del Combustible [F]                             1245 non-null   object
#  17  Presion del Riel de Combustible Medi [psi]                            1245 non-null   object
#  18  Presion del Riel de Sincronizacion [psi]                              1245 non-null   object
#  19  Indice de Combustible Instant�neo [gph]                               1245 non-null   object
#  20  Voltaje 1 de la Bateria [V]                                           1245 non-null   object
#  21  Instantaneous Power Output [hp]                                       1245 non-null   object
#  22  Sensor de Temperatura de Escape del Cilindro 1 [F]                    1245 non-null   object
#  23  Sensor de Temperatura de Escape del Cilindro 2 [F]                    1245 non-null   object
#  24  Sensor de Temperatura de Escape del Cilindro 3 [F]                    1245 non-null   object
#  25  Sensor de Temperatura de Escape del Cilindro 4 [F]                    1245 non-null   object
#  26  Sensor de Temperatura de Escape del Cilindro 5 [F]                    1245 non-null   object
#  27  Sensor de Temperatura de Escape del Cilindro 6 [F]                    1245 non-null   object
#  28  Sensor de Temperatura de Escape del Cilindro 7 [F]                    1245 non-null   object
#  29  Sensor de Temperatura de Escape del Cilindro 8 [F]                    1245 non-null   object
#  30  Sensor de Temperatura de Escape del Cilindro 9 [F]                    1245 non-null   object
#  31  Sensor de Temperatura de Escape del Cilindro 10 [F]                   1245 non-null   object
#  32  Sensor de Temperatura de Escape del Cilindro 11 [F]                   1245 non-null   object
#  33  Sensor de Temperatura de Escape del Cilindro 12 [F]                   1245 non-null   object
#  34  Sensor de Temperatura de Escape del Cilindro 13 [F]                   1245 non-null   object
#  35  Sensor de Temperatura de Escape del Cilindro 14 [F]                   1245 non-null   object
#  36  Sensor de Temperatura de Escape del Cilindro 15 [F]                   1245 non-null   object
#  37  Sensor de Temperatura de Escape del Cilindro 16 [F]                   1245 non-null   object
#  38  Temperatura Promedio de Escape (Calculada) [F]                        1245 non-null   object
#  39  Temperatura Promedio de Escape - Banco Izquierdo (Calculada) [F]      1245 non-null   object
#  40  Temperatura Promedio de Escape - Banco Derecho (Calculada) [F]        1245 non-null   object
#  41  Sensor 1 de Presion del Multiple de Admi [in Hg]                      1245 non-null   object
#  42  Sensor 2 de Presion del Multiple de Admi [in Hg]                      1245 non-null   object
#  43  Sensor 1 de Temperatura del Multiple de Admisi [F]                    1245 non-null   object
#  44  Sensor 2 de Temperatura del Multiple de Admisi [F]                    1245 non-null   object
#  45  Sensor 3 de Temperatura del Multiple de Admisi [F]                    1245 non-null   object
#  46  Sensor 4 de Temperatura del Multiple de Admisi [F]                    1245 non-null   object
#  47  Sensor de Temperatura 1 Delta del Multiple de Admision (Calcul [F]    1245 non-null   object
#  48  Sensor de Temperatura 2 Delta del Multiple de Admision (Calcul [F]    1245 non-null   object
#  49  Sensor de Temperatura 3 Delta del Multiple de Admision (Calcul [F]    1245 non-null   object
#  50  Sensor de Temperatura 4 Delta del Multiple de Admision (Calcul [F]    1245 non-null   object
#  51  Carga Neta Porcentual [Percent]                                       1245 non-null   object
#  52  Estado del Motor                                                      1245 non-null   object
# dtypes: object(53)
# memory usage: 515.6+ KB

# %%
df.describe()
# Out:
#        Evento   Tiempo Real Tiempo del Motor  \
# count    1245          1245             1245
# unique   1245             1             1245
# top      1245  Sin Preparar     002096:07:27
# freq        1          1245                1
#
#        Tiempo de Operacion de Reconstruccion del M [HHHHHH:MM]  \
# count                                                1245
# unique                                                967
# top                                            0002081:26
# freq                                                    4
#
#        Velocidad del Motor [rpm]  \
# count                       1245
# unique                       349
# top                         1846
# freq                          14
#
#        Por Ciento de Pedal o Palanca del Acelerador [Percent]  \
# count                                                1245
# unique                                                 31
# top                                                   100
# freq                                                  736
#
#        Temperatura del Refrigerante del Motor [F]  \
# count                                        1245
# unique                                         22
# top                                         188.6
# freq                                          131
#
#        Sensor de Presion del Refrigeran [in Hg]  \
# count                                      1245
# unique                                       43
# top                                          38
# freq                                        110
#
#        Presion de Aceite del Mot [psi] Temperatura de Aceite del Motor [F]  \
# count                             1245                                1245
# unique                              40                                 328
# top                               67.9                               210.6
# freq                               102                                  17
#
#         ... Sensor 1 de Temperatura del Multiple de Admisi [F]  \
# count   ...                                               1245
# unique  ...                                                 28
# top     ...                                                140
# freq    ...                                                136
#
#        Sensor 2 de Temperatura del Multiple de Admisi [F]  \
# count                                                1245
# unique                                                 46
# top                                                   136
# freq                                                   65
#
#        Sensor 3 de Temperatura del Multiple de Admisi [F]  \
# count                                                1245
# unique                                                 46
# top                                                   140
# freq                                                   69
#
#        Sensor 4 de Temperatura del Multiple de Admisi [F]  \
# count                                                1245
# unique                                                 47
# top                                                   144
# freq                                                   76
#
#        Sensor de Temperatura 1 Delta del Multiple de Admision (Calcul [F]  \
# count                                                1245
# unique                                                  4
# top                                                    32
# freq                                                  798
#
#        Sensor de Temperatura 2 Delta del Multiple de Admision (Calcul [F]  \
# count                                                1245
# unique                                                  5
# top                                                    33
# freq                                                  601
#
#        Sensor de Temperatura 3 Delta del Multiple de Admision (Calcul [F]  \
# count                                                1245
# unique                                                  5
# top                                                    32
# freq                                                  680
#
#        Sensor de Temperatura 4 Delta del Multiple de Admision (Calcul [F]  \
# count                                                1245
# unique                                                  5
# top                                                    32
# freq                                                  638
#
#        Carga Neta Porcentual [Percent] Estado del Motor
# count                             1245             1245
# unique                              71                1
# top                                 94      Funcionando
# freq                                48             1245
#
# [4 rows x 53 columns]
